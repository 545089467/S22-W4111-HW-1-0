# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
#
# }
#
# </style>
#
# <b><center>
#     <span style="font-size: 24pt; line-height: 1.2;">COMS W4111: Introduction to Databases</span><br>
#     <span style="font-size: 24pt; line-height: 1.2;">Section 002/V02, Spring, 2022</span><br>
# </center></b>
# <br><br>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2;">HW 1 Notebook</span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook has three top level sections:
# 1. _Setup_ tests the environment setup, and should work assuming you completed HW0.
# 1. _Common Tasks_ are the HW1 tasks for both the programming and non-programming track. All students complete this section.
# 2. _Non-Programing Track_ contains the tasks that students in the non-programming track must complete.
# 3. _Programming Track_ contains the tasks that students in the programming track must complete.
#
#
# Submission format:
#
# - All students (both tracks) submit a completed version of this notebook. Students need to complete the setup section, the common section, and the section specific to their track. The submission format is a PDF generated from the notebook. Students can generate the PDF by:
#     - Choosing ```File->Print Preview``` in the notebook's menu bar. This will open a new browser tab.
#     - In the new browser tab, select ```File->Print``` and choose to save as PDF.
#     - **Make sure that everything renders properly in the generated PDF.** Troubleshoot/reach out if you have issues. Images/outputs that render incorrectly will not be graded.
#
#
# - All students submit a zip file containing their cloned HW0/1 project, which they got by cloning the [GitHub repository.](https://github.com/donald-f-ferguson/S22-W4111-HW-1-0) Students can:
#     - Open a command/terminal window in the root directory where they cloned the project.
#     - Enter ```git pull``` to retrieve any updates to the project, including required data files.
#
#
# - Students can edit the notebook using Anaconda Navigator to open Jupyter Notebook.
#
#
#
# - Students on the programming track also create and modify Python files in the sub-folder ```<UNI>_web_src```. Remember, you should be using a folder with your UNI. In my case, the folder would be ```dff9_web_src.```
#
#
#
# - The zip file you submit should contain __only__ the following sub-folders/files:
#     - ```<UNI>_src.``` (All students) This folder must container your version of this notebook.
#     - ```<UNI>_web_src.``` (Only programming track)
#     - To be clear: the zipped directory for non-programming track submissions should contain **one** file. The corresponding ``zip`` for the programming track should contain **two** files.
#
#
# - Make sure to submit your notebook in the PDF format separately from the zip file, based on your track as well. That is, you need to make __two__ submissions in total like below:
#     - Submit your notebook file in PDF format to ```Homework 1: Non-programming or Programming``` __(Make sure that you assigned pages properly).__
#     - Submit your zip file to ```Homework 1: Zip File Submission```

# %% [markdown]
# # Setup
#
# __Note:__ You will have to put the correct user ID and password in the connection strings below, e.g. replace ```dbuser``` and ```dbuserdbuser.```

# %% [markdown]
# ## iPython-SQL

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:123456@localhost
# Out:
# 'Connected: root@None'

# %%
# %sql select * from db_book.student where name like "z%" or name like "sh%"
# Out:
#  * mysql+pymysql://root:***@localhost
# 2 rows affected.
# [('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32'))]

# %% [markdown]
# ## PyMySQL

# %%
import pymysql

# %%
conn = pymysql.connect(host="localhost", user="root", password="123456")

# %%
sql = """
    select * from db_book.student where
        name like %s or name like %s
"""

# %%
pattern_1 = "z%"
pattern_2 = "sh%"

# %%
cur = conn.cursor()
res = cur.execute(
    sql, args=(pattern_1, pattern_2)
)
res = cur.fetchall()

# %%
res
# Out:
# (('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32')))

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
#
#  Replace the path below with the path of your project directory.
#  Use // instead of / if you're on Windows.
#
project_root = "D://OneDrive//Documents//4111//S22-W4111-HW-1-0"

# %%
people_df = pd.read_csv(project_root + "/data/People.csv")

# %%
people_df.loc[
    (people_df['nameLast'] == "Williams") & (people_df['birthCity'] == 'San Diego'),
    ["playerID", "nameLast", "nameFirst", "birthYear", 'birthCity', 'bats', 'throws']
]
# Out:
#         playerID  nameLast nameFirst  birthYear  birthCity bats throws
# 19773  willite01  Williams       Ted     1918.0  San Diego    L      R
# 19776  willitr01  Williams    Trevor     1992.0  San Diego    R      R

# %% [markdown]
# ## SQLAlchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:123456@localhost")

# %%
sql = """
    select * from db_book.student where
        name like %s or name like %s
"""
pattern_1 = "z%"
pattern_2 = "sh%"

# %%
another_df = pd.read_sql(sql, params=(pattern_1, pattern_2), con=engine)
another_df
# Out:
#       ID     name   dept_name  tot_cred
# 0  00128    Zhang  Comp. Sci.     102.0
# 1  12345  Shankar  Comp. Sci.      32.0

# %% [markdown]
# # Common Tasks

# %% [markdown]
# ## Schema and Data Modeling

# %% [markdown]
# - There are three entity types:
#     1. Employee with attributes:
#         - employee_no
#         - last_name
#         - first_name
#     2. Department with attributes
#         - department_id
#         - department_name
#     3. Applicant with attributes:
#         - email
#         - last_name
#         - first_name

# %% [markdown]
# ### Relational Schema
#
# - Using the notation from the textbook slides and lecture notes, define the relation definitions for each of the entity types. That is, the schema definition for the relations. You will need to choose a primary key.
#
#
# - The snippet below shows how to use under-bar.

# %% [markdown]
# \begin{equation}
# This\ is\ a\ sentence\ with\ someting\_in\_parentheses(
#     \underline{something}, another\_thing)\  and\ something\ with\ underbar.
# \end{equation}

# %% [markdown]
# You can double click on the cell above to see the source, which is
# ```
# \begin{equation}
# This\ is\ a\ sentence\ with\ someting\_in\_parentheses(
#     \underline{something}, another\_thing)\  and\ something\ with\ underbar.
# \end{equation}
# ```

# %% [markdown]
# Put your relation definitions below between the horizontal lines.
#
# <hr style="height: 1px";>
#
# \begin{equation}
# Employee( \underline{employee\_no}, last\_name, first\_name)
# \newline
# Department( \underline{department\_id}, department\_name)
# \newline
# Applicant( \underline{email}, last\_name, first\_name)
# \end{equation}
#
#
# <hr style="height: 1px";>

# %% [markdown]
# ### ER Modeling
#
# - Continuing the example above:
#     - An _employee_ is a _member\_of_ exactly one department.
#     - An _applicant_ has exactly one _employee_ who is _sponsor\_of_ of the applicant.
#     - An _applicant_ may have specified a _department_ that is the _applicant's_ _preferred\_dept._
#
#
# - Use [Lucidchart](https://www.lucidchart.com) to draw the logical diagram.
#
#
# - __Note:__ You may have to add columns/attributes to some tables to implement the relationships.
#
#
# - To submit the diagram, take a screen capture and modify the cell below to load your diagram from the file system. The following is an example for how to include the screenshot.

# %%
er_model_file_name = 'js_diagram.png'

print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# ## Relational Algebra
#
# ### Instructions
#
# - You will use the [RelaX](https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0) online relational algebra calculator.
#
#
# - You must use the dataset ```Silberschatz - UniversityDB.``` I demonstrated how to select a dataset during a lecture.
#
#
# - For submitting your answer, you must:
#     - Cut and paste your relational expression in text.
#     - Take a screenshot and include the image.
#
#
# - The following is an example question and answer.

# %% [markdown]
# ### Example
#
# __Question:__ Produce a table of the form ```(course_id, title, prereq_id, preqreq_title)``` that lists courses and their prereqs.
#
#
# <hr style="height:1px;">
#
# ```
# π course_id, title, prereq_id, prereq_title
# 	(
# 		(π course_id, title, prereq_id (course ⨝ prereq))
# 		⨝ prereq_id=x
# 		(π x←course_id, prereq_title←title (course))
# )
# ```

# %%
er_model_file_name = 'sample_answer_q.png'

print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### Relational Algebra Q1

# %% [markdown]
# - Use ```student, advisor``` and ```instructor``` for this question.
#
#
# - Produce a table of the form ```(student.ID, student.name, instructor.ID, instructor.name)``` that shows students and their advisors.

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### Put you relational algebra and loading screenshot here.

# %% [markdown]
# <hr style="height:1px;">
#
# ```
# π student.ID, student.name, instructor.ID, instructor.name (
# student ⨝ student.ID=advisor.s_id
# (advisor ⨝ advisor.i_id=instructor.ID instructor))
# ```

# %%
ra1_file_name = 'ra1.png'

print("\n")
from IPython.display import Image
Image(filename=ra1_file_name)

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### Relational Algebra Q2

# %% [markdown]
# - Use ```student``` and ```takes``` for this question.
#
#
# - Produce a table of the form ```(student.ID, student.name, student,tot_cred, student_dept_name)``` for students that have not taken any course/section.

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# Put you relational algebra and loading screenshot here.

# %% [markdown]
# ```
# π student.ID,student.name,student.tot_cred,student.dept_name student -
# (π student.ID,student.name,student.tot_cred,student.dept_name (
# 	student ⨝ student.ID=takes.ID takes
# ))
#
# ```

# %%
ra2_file_name = 'ra2.png'

print("\n")
from IPython.display import Image
Image(filename=ra2_file_name)

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ## SQL

# %% [markdown]
# ### Instructions
#
# - The questions in this section ask you to write and execute SQL statements.
#
#
# - Your answer should be a code cell with ```%sql``` and your query.
#
#
# - You must execute the query.

# %% [markdown]
# ### Example
#
# - This is the SQL version of the query from the relational algebra section above.

# %% [markdown]
# <hr style="height: 1px;">

# %%
# %%sql
# use db_book;
#
# select a.course_id as course_id,
#        a.title as title,
#        prereq_id,
#        b.title as prereq_tiles
# from
#               (select course_id, title, prereq_id from course join prereq using(course_id)) as a
# join
#     course as b on a.prereq_id=b.course_id
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 7 rows affected.
# [('BIO-301', 'Genetics', 'BIO-101', 'Intro. to Biology'),
#  ('BIO-399', 'Computational Biology', 'BIO-101', 'Intro. to Biology'),
#  ('CS-190', 'Game Design', 'CS-101', 'Intro. to Computer Science'),
#  ('CS-315', 'Robotics', 'CS-101', 'Intro. to Computer Science'),
#  ('CS-319', 'Image Processing', 'CS-101', 'Intro. to Computer Science'),
#  ('CS-347', 'Database System Concepts', 'CS-101', 'Intro. to Computer Science'),
#  ('EE-181', 'Intro. to Digital Systems', 'PHY-101', 'Physical Principles')]

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### SQL Question 1
#
# - Translate your answer from Relational Algebra Q1 into SQL.
#
#
# - Do not worry about correctly naming the columns.

# %% [markdown]
# <hr style="height: 1px">

# %%
# %%sql
#
# use db_book;
#
# select s.ID as student_id, s.name as studnet_name, ai.ID as instructor_ID, ai.name as instructure_name
# from
# (select *
# from advisor a
# join instructor i on a.i_ID = i.ID) as ai
# join student s on s.ID = ai.s_ID
# order by student_id;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 9 rows affected.
# [('00128', 'Zhang', '45565', 'Katz'),
#  ('12345', 'Shankar', '10101', 'Srinivasan'),
#  ('23121', 'Chavez', '76543', 'Singh'),
#  ('44553', 'Peltier', '22222', 'Einstein'),
#  ('45678', 'Levy', '22222', 'Einstein'),
#  ('76543', 'Brown', '45565', 'Katz'),
#  ('76653', 'Aoi', '98345', 'Kim'),
#  ('98765', 'Bourikas', '98345', 'Kim'),
#  ('98988', 'Tanaka', '76766', 'Crick')]

# %% [markdown]
# <hr style="height: 1px">

# %% [markdown]
# ### SQL Question 2
#
# - You guessed it.
#
#
# - Translate your answer from Relational Algebra Q2 into SQL.
#
#
# - Do not worry about correctly naming the columns.

# %% [markdown]
# <hr style="height: 1px">

# %%
# %%sql
#
# use db_book;
#
# select s.ID,s.name,s.tot_cred,s.dept_name
# from student s
# left join takes t on s.ID = t.ID
# where t.ID is NULL
# ;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1 rows affected.
# [('70557', 'Snow', Decimal('0'), 'Physics')]

# %% [markdown]
# <hr style="height: 1px">

# %% [markdown]
# ### SQL Question 3
#
#
# - The following query makes a copy of the ```department``` table.

# %%
# %%sql
#
# drop table if exists hw1_department;
# create table hw1_department as select * from department
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 7 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-75-1fdf3fc7bcd0> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\ndrop table if exists hw1_department;\ncreate table hw1_department as select * from department\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# - The next query shows the content.

# %%
# %sql select * from db_book.hw1_department
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('Biology', 'Watson', Decimal('90000.00')),
#  ('Comp. Sci.', 'Taylor', Decimal('100000.00')),
#  ('Elec. Eng.', 'Taylor', Decimal('85000.00')),
#  ('Finance', 'Painter', Decimal('120000.00')),
#  ('History', 'Painter', Decimal('50000.00')),
#  ('Music', 'Packard', Decimal('80000.00')),
#  ('Physics', 'Watson', Decimal('70000.00'))]

# %% [markdown]
# - You have two tasks for this question.
#     1. Create a new table ```db_book.hw1_schools``` that has columns ```school_id``` and ```school_name.```
#     2. Modify table ```db_boot.hw1_department``` to contain a columns ```school_id.```
#
#
# - __Notes:__
#     - You do not have to worry about foreign keys.
#     - You do not need to populate any data or link ```school_id``` to the ```hw1_schools.```
#     - You can use DataGrip or another tool to produce the SQL DDL, but you must show successful execution on the code cells below.

# %% [markdown]
# <hr style="height: 1px">

# %%
# %%sql
# use db_book;
#
# create table if not exists hw1_schools
# (
#     school_id   varchar(10) not null
#         primary key,
#     school_name varchar(52) null
# );
#
# alter table hw1_department
#     add school_id varchar(52) null;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-77-c2426c37a87b> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'use db_book;\n\ncreate table if not exists hw1_schools\n(\n    school_id   varchar(10) not null\n        primary key,\n    school_name varchar(52) null\n);\n\nalter table hw1_department\n    add school_id varchar(52) null;\n\n\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# <hr style="height: 1px">

# %% [markdown]
# # Non-Programming Track

# %% [markdown]
# ## Tasks

# %% [markdown]
# - There is a subdirectory in the project ```data/GoT``` that contains three CSV files:
#     - ```characters.csv```
#     - ```episodes.csv```
#     - ```character_relationships.csv```
#
#
# - Your first task is to create tables to hold the data.
#     - This means you must create three tables. Use a new schema and create the three tables:
#         - ```S22_W4111_HW1.characters```
#         - ```S22_W4111_HW1.episodes```
#         - ```S22_W4111_HW1.character_relationships.```
#     - The table must have a column for each of the columns in the CSV.
#     - You can use DataGrip or another tool to produce the create table statements, but you must execute the DDL statements in the code cells.
#
#
# - Your second task is to load the data from the CSV files into the newly created tables. Do do this, you use a ```LOAD``` statement.
#
#
# - Finally, you should examine the data and change column types to better reflect the actual values in the columns.
#
#
# - To make the instruction more clear, I do an example of the tasks for another table. This is ```got_imdb_names.csv.``` You will do similar steps for the files above.

# %% [markdown]
# ## Example

# %% [markdown]
# - Manual examining the CSV file shows that the data has the following attributes.
#     - ```nconst```
#     - ```primaryName```
#     - ```birthYear```
#     - ```deathYear```
#     - ```primaryProfession```
#     - ```knownForTitles```
#
#
# - So, my first step is to create a table to hold the information.
#
#
# - __Note:__ I have dozens of schema. So, I am prefixing this one with ```aaaa_``` to make it easy for me to find. You can drop this prefix.
#
#
# - The following are the statements for creating the schema and table.

# %%
# Create the schema if it does not exist.
# %sql create schema if not exists aaaa_S22_W4111_HW1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-78-e4b39979fb38> in <module>
#       1 # Create the schema if it does not exist.
# ----> 2 get_ipython().run_line_magic('sql', 'create schema if not exists aaaa_S22_W4111_HW1;')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Drop the table if it exists.
# %sql drop table if exists aaaa_S22_W4111_HW1.got_imdb_actors;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-79-1c998c6140ef> in <module>
#       1 # Drop the table if it exists.
# ----> 2 get_ipython().run_line_magic('sql', 'drop table if exists aaaa_S22_W4111_HW1.got_imdb_actors;')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# - Now create the table.

# %%
# %%sql
# create table if not exists aaaa_S22_W4111_HW1.got_imdb_actors
# (
# 	nconst text null,
# 	primaryName text null,
# 	birthYear text null,
# 	deathYear text null,
# 	primaryProfession text null,
# 	knownForTitles text null
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-80-5ead6fce4f6e> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'create table if not exists aaaa_S22_W4111_HW1.got_imdb_actors\n(\n\tnconst text null,\n\tprimaryName text null,\n\tbirthYear text null,\n\tdeathYear text null,\n\tprimaryProfession text null,\n\tknownForTitles text null\n);\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# - This is where it gets real and you do some wizard stuff.

# %%
# This command allows loading CSV files from the local disk.
# This is set of OFF by default.
# You should only have to run this once, that is if you execute the example, you do not need to do again.
#
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-81-3dae89daab24> in <module>
#       3 # You should only have to run this once, that is if you execute the example, you do not need to do again.
#       4 #
# ----> 5 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# This is creating a connection to the database.
# You need to replace the user and passsword with your values for your installation of MySQL.
# Do not ask about the local_infile. That is Voldemort stuff.
#
con = pymysql.connect(host="localhost",
                        user="root",
                        password="123456",
                        autocommit=True,
                        local_infile=1)

# %%
# This statement performs the load.
# You will need to change the TABLE name and the INFILE to the correct values.
#
sql = """
LOAD DATA LOCAL INFILE
'D://OneDrive//Documents//4111//S22-W4111-HW-1-0//data//GoT//got_imdb_actors.csv'
INTO TABLE aaaa_S22_W4111_HW1.got_imdb_actors
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
# Create a cursor. Again. Voldemort stuff, or maybe Sauron stuff.
#
cur = con.cursor()

# %%
# Run the sql
cur.execute(sql)
# Out:
# 113

# %%
# Close the cursor. Sort of like the opposite of alohomora
cur.close()

# %%
#  ('nm3310211', 'Rose Leslie', '1987', '', 'actress', 'tt4520364,tt1618442,tt0944947,tt3177316"\r\nnm0889338,Rupert Vansittart,1958,,actor,"tt0109831,tt0112573,tt0944947,tt0107943"\r\nnm0535837,Francis Magee,1969,,actor,"tt3748528,tt0974015,tt12361974,tt0375912"\r\nnm5502295,Matteo Elezi,,,"actor,visual_effects,miscellaneous'),
#  ('nm5309709', 'Nell Williams', '', '', 'actress', 'tt5563334,tt0944947,tt8266310,tt3154822"\r\nnm8108764,Cordelia Hill,,,actress,tt0944947\r\nnm1519719,Annette Tierney,,,actress,"tt0490539,tt0944947,t ... (144 characters truncated) ... 0,tt3454424,tt2628232,tt0944947"\r\nnm7509186,Fergus Leathem,,,actor,"tt6282542,tt0944947"\r\nnm0503319,Gerald Lepkowski,1966,,"actor,director,writer')]

# %%
# %sql select * from aaaa_S22_W4111_HW1.characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# (pymysql.err.ProgrammingError) (1146, "Table 'aaaa_s22_w4111_hw1.characters' doesn't exist")
# [SQL: select * from aaaa_S22_W4111_HW1.characters;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %% [markdown]
# - The final part of the task for each of the tables will be making some corrections.
#
#
# - We would only ask you to do two or three corrections per table.
#
#
# - Mine for this example would be in the following.

# %%
# %%sql
#
# use aaaa_S22_W4111_HW1;
#
# alter table got_imdb_actors modify nconst varchar(12) null;
#
# alter table got_imdb_actors modify primaryName varchar(256) null;
#
# alter table got_imdb_actors modify birthYear char(4) null;
#
# alter table got_imdb_actors modify deathYear char(4) null;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 113 rows affected.
# 113 rows affected.
# 113 rows affected.
# 113 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-90-0c0bcfc4c9d1> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nuse aaaa_S22_W4111_HW1;\n\nalter table got_imdb_actors modify nconst varchar(12) null;\n\nalter table got_imdb_actors modify primaryName varchar(256) null;\n\nalter table got_imdb_actors modify birthYear char(4) null;\n\nalter table got_imdb_actors modify deathYear char(4) null;\n\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# ## Characters
#
# - Perform the tasks for characters.

# %%
# Create the schema if it does not exist.
# %sql create schema if not exists S22_W4111_HW1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-100-5fd16648b9af> in <module>
#       1 # Create the schema if it does not exist.
# ----> 2 get_ipython().run_line_magic('sql', 'create schema if not exists S22_W4111_HW1;')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Drop the table if it exists.
# %sql drop table if exists S22_W4111_HW1.characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-101-b56a9bba8519> in <module>
#       1 # Drop the table if it exists.
# ----> 2 get_ipython().run_line_magic('sql', 'drop table if exists S22_W4111_HW1.characters;')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# create table if not exists S22_W4111_HW1.characters
# (
# 	characterName text null,
# 	characterLink text null,
# 	actorName text null,
# 	actorLink text null,
# 	id text null,
# 	royal text null,
# 	characterImageThumb text null,
# 	characterImageFull text null,
# 	nickname text null,
# 	kingsguard text null
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-102-8565f5d8d405> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'create table if not exists S22_W4111_HW1.characters\n(\n\tcharacterName text null,\n\tcharacterLink text null,\n\tactorName text null,\n\tactorLink text null,\n\tid text null,\n\troyal text null,\n\tcharacterImageThumb text null,\n\tcharacterImageFull text null,\n\tnickname text null,\n\tkingsguard text null\n);\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-103-510c5aa62121> in <module>
# ----> 1 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
con = pymysql.connect(host="localhost",
                        user="root",
                        password="123456",
                        autocommit=True,
                        local_infile=1)

# %%
sql = """
LOAD DATA LOCAL INFILE
'D://OneDrive//Documents//4111//S22-W4111-HW-1-0//data//GoT//characters.csv'
INTO TABLE S22_W4111_HW1.characters
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
cur = con.cursor()

# %%
cur.execute(sql)
# Out:
# 389

# %%
cur.close()

# %%
# %sql select * from S22_W4111_HW1.characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 389 rows affected.
# [('Addam Marbrand', '/character/ch0305333/', 'B.J. Hogg', '/name/nm0389698/', '6191091c06029e3acded09e1', '', '', '', '', '\r'),
#  ('Aegon Targaryen', '', '', '', '6191091c06029e3acded09e2', '1', '', '', '', '\r'),
#  ('Aeron Greyjoy', '/character/ch0540081/', 'Michael Feast', '/name/nm0269923/', '6191091c06029e3acded09e3', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5B
 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTJjYzk1MGMtNjE3Mi00NjE2LTkzMWUtNGRjODVlY2JmMmI5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNTJjYzk1MGMtNjE3Mi00NjE2LTkzMWUtNGRjODVlY2JmMmI5XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', '\r')]

# %%
# %%sql
#
# use S22_W4111_HW1;
#
#
# alter table characters
#     modify characterName varchar(52) not null;
#
# alter table characters
#     modify characterLink varchar(52) null;
#
# alter table characters
#     modify id varchar(52) not null;
#
# alter table characters
#     add constraint characters_pk
#         primary key (id);
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 389 rows affected.
# 389 rows affected.
# 389 rows affected.
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-110-3edd8ec13029> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nuse S22_W4111_HW1;\n\n\nalter table characters\n    modify characterName varchar(52) not null;\n\nalter table characters\n    modify characterLink varchar(52) null;\n\nalter table characters\n    modify id varchar(52) not null;\n\nalter table characters\n    add constraint characters_pk\n        primary key (id);\n\n\n\n\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# ## Episodes
#
# - Perform the tasks for episodes.

# %%
# %sql drop table if exists S22_W4111_HW1.episodes;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-116-b4f403df44fd> in <module>
# ----> 1 get_ipython().run_line_magic('sql', 'drop table if exists S22_W4111_HW1.episodes;')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# create table if not exists S22_W4111_HW1.episodes
# (
# 	seasonNum text null,
# 	episodeNum text null,
# 	sceneNum text null,
# 	sceneLocation text null,
# 	sceneSubLocation text null,
# 	sceneStartTime text null,
# 	sceneEndTime text null
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-117-b2cd00055f38> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'create table if not exists S22_W4111_HW1.episodes\n(\n\tseasonNum text null,\n\tepisodeNum text null,\n\tsceneNum text null,\n\tsceneLocation text null,\n\tsceneSubLocation text null,\n\tsceneStartTime text null,\n\tsceneEndTime text null\n);\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-118-510c5aa62121> in <module>
# ----> 1 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
con = pymysql.connect(host="localhost",
                        user="root",
                        password="123456",
                        autocommit=True,
                        local_infile=1)

# %%
sql = """
LOAD DATA LOCAL INFILE
'D://OneDrive//Documents//4111//S22-W4111-HW-1-0//data//GoT//episodes.csv'
INTO TABLE S22_W4111_HW1.episodes
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
cur = con.cursor()

# %%
cur.execute(sql)
# Out:
# 4165

# %%
cur.close()

# %%
# %sql select * from S22_W4111_HW1.episodes;
# Out:
#  * mysql+pymysql://root:***@localhost
# 4165 rows affected.
#  ('3', '6', '6', 'The Riverlands', 'Hollow Hill', '0:13:36', '0:14:53\r'),
#  ('3', '6', '7', 'The Riverlands', 'Hollow Hill', '0:14:53', '0:18:03\r'),
#  ('3', '6', '8', 'The Riverlands', 'Hollow Hill', '0:18:03', '0:20:38\r'),
#  ('3', '6', '9', 'North of the Wall', 'The Wall', '0:20:38', '0:22:07\r'),
#  ('3', '6', '10', 'The North', 'The Dreadfort', '0:22:07', '0:27:39\r'),
#  ('3', '6', '11', 'The Riverlands', 'Riverrun', '0:27:39', '0:29:42\r'),
#  ('3', '6', '12', 'The Riverlands', 'Riverrun', '0:29:42', '0:31:25\r'),
#  ('3', '6', '13', 'The Riverlands', 'Harrenhal', '0:31:25', '0:33:43\r'),
#  ('3', '6', '14', 'The Crownlands', "King's Landing", '0:33:43', '0:37:28\r'),
#  ('3', '6', '15', 'North of the Wall', 'The Wall', '0:37:28', '0:40:07\r'),
#  ('3', '6', '16', 'The Crownlands', "King's Landing", '0:40:07', '0:41:41\r'),
#  ('3', '6', '17', 'The Crownlands', "King's Landing", '0:41:41', '0:44:33\r'),
#  ...]

# %%
# %%sql
#
# use S22_W4111_HW1;
#
# alter table episodes
#     modify seasonNum varchar(10) not null;
#
# alter table episodes
#     modify episodeNum varchar(10) not null;
#
# alter table episodes
#     modify sceneLocation varchar(128) null;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 4165 rows affected.
# 4165 rows affected.
# 4165 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-130-56a16e683910> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nuse S22_W4111_HW1;\n\nalter table episodes\n    modify seasonNum varchar(10) not null;\n\nalter table episodes\n    modify episodeNum varchar(10) not null;\n\nalter table episodes\n    modify sceneLocation varchar(128) null;\n\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# ## Characters Relatrionships
#
# - Perform the tasks for character_relationships.

# %%
# %sql drop table if exists S22_W4111_HW1.character_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-131-6aad7c00f9d8> in <module>
# ----> 1 get_ipython().run_line_magic('sql', 'drop table if exists S22_W4111_HW1.character_relationships;')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# create table if not exists S22_W4111_HW1.character_relationships
# (
# 	source_character_id text null,
# 	sourceCharacterName text null,
# 	relationship text null,
# 	target_character_id text null,
# 	targetCharacterName text null
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-132-5b5d93cde8f0> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', 'create table if not exists S22_W4111_HW1.character_relationships\n(\n\tsource_character_id text null,\n\tsourceCharacterName text null,\n\trelationship text null,\n\ttarget_character_id text null,\n\ttargetCharacterName text null\n);\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-133-510c5aa62121> in <module>
# ----> 1 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
con = pymysql.connect(host="localhost",
                        user="root",
                        password="123456",
                        autocommit=True,
                        local_infile=1)

# %%
sql = """
LOAD DATA LOCAL INFILE
'D://OneDrive//Documents//4111//S22-W4111-HW-1-0//data//GoT//character_relationships.csv'
INTO TABLE S22_W4111_HW1.character_relationships
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
cur = con.cursor()

# %%
cur.execute(sql)
# Out:
# 785

# %%
cur.close()

# %%
# %sql select * from S22_W4111_HW1.character_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost
# 785 rows affected.
# [('6191091c06029e3acded09e2', 'Aegon Targaryen', 'parents', '6191091c06029e3acded0a20', 'Elia Martell'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'killedBy', '6191091c06029e3acded0a38', 'Gregor Clegane'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'siblings', '6191091c06029e3acded0a5c', 'Jon Snow'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'parents', '6191091c06029e3acded0af8', 'Rhaegar Targaryen'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'siblings', '6191091c06029e3acded0afb', 'Rhaenys Targaryen'),
#  ('6191091c06029e3acded09e3', 'Aeron Greyjoy', 'siblings', '6191091c06029e3acded09f2', 'Balon Greyjoy'),
#  ('6191091c06029e3acded09e3', 'Aeron Greyjoy', 'siblings', '6191091c06029e3acded0a22', 'Euron Greyjoy'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'servedBy', '6191091c06029e3acded09ef', 'Arthur Dayne'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'killed', '6191091c06029e3acded09fd', 'Brandon Stark'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'parentOf', '6191091c06029e3acded0a0d', 'Daenerys Targaryen'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'killedBy', '6191091c06029e3acded0a52', 'Jaime Lannister'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'servedBy', '6191091c06029e3acded0a52', 'Jaime Lannister'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'parentOf', '6191091c06029e3acded0af8', 'Rhaegar Targaryen'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'marriedEngaged', '6191091c06029e3acded0afa', 'Rhaella Targaryen'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'siblings', '6191091c06029e3acded0afa', 'Rhaella Targaryen'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'killed', '6191091c06029e3acded0afd', 'Rickard Stark'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'parentOf', '6191091c06029e3acded0b44', 'Viserys Targaryen'),
#  ('6191091c06029e3acded09e5', 'Akho', 'killedBy', '6191091c06029e3acded0a0c', 'Daario Naharis'),
#  ('6191091c06029e3acded09e6', 'Alliser Thorne', 'killed', '6191091c06029e3acded0a5c', 'Jon Snow'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'servedBy', '6191091c06029e3acded0ab9', 'Missandei'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'killed', '6191091c06029e3acded0aef', 'Randyll Tarly'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'guardedBy', '6191091c06029e3acded0af7', 'Rhaegal'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'siblings', '6191091c06029e3acded0af8', 'Rhaegar Targaryen'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'parentOf', '6191091c06029e3acded0af9', 'Rhaego'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'parents', '6191091c06029e3acded0afa', 'Rhaella Targaryen'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'servedBy', '6191091c06029e3acded0b3e', 'Tyrion Lannister'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'guardedBy', '6191091c06029e3acded0b43', 'Viserion'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'siblings', '6191091c06029e3acded0b44', 'Viserys Targaryen'),
#  ('6191091c06029e3acded0a0d', 'Daenerys Targaryen', 'killed', '6191091c06029e3acded0b58', 'Xaro Xhoan Daxos'),
#  ('6191091c06029e3acded0a10', 'Davos Seaworth', 'serves', '6191091c06029e3acded0a5c', 'Jon Snow'),
#  ('6191091c06029e3acded0a10', 'Davos Seaworth', 'parentOf', '6191091c06029e3acded0aad', 'Matthos Seaworth'),
#  ('6191091c06029e3acded0a10', 'Davos Seaworth', 'serves', '6191091c06029e3acded0b1d', 'Stannis Baratheon'),
#  ('6191091c06029e3acded0a11', 'Dickon Tarly', 'killedBy', '6191091c06029e3acded0a0d', 'Daenerys Targaryen'),
#  ('6191091c06029e3acded0a11', 'Dickon Tarly', 'parents', '6191091c06029e3acded0ab0', 'Melessa Tarly'),
#  ('6191091c06029e3acded0a11', 'Dickon Tarly', 'parents', '6191091c06029e3acded0aef', 'Randyll Tarly'),
#  ('6191091c06029e3acded0a11', 'Dickon Tarly', 'siblings', '6191091c06029e3acded0b0b', 'Samwell Tarly'),
#  ('6191091c06029e3acded0a11', 'Dickon Tarly', 'siblings', '6191091c06029e3acded0b2a', 'Talla Tarly'),
#  ('6191091c06029e3acded0a12', 'Dongo the Giant', 'killedBy', '6191091c06029e3acded0acc', "Night's Watchman"),
#  ('6191091c06029e3acded0a12', 'Dongo the Giant', 'killedBy', '6191091c06029e3acded0acd', "Night's Watchman"),
#  ('6191091c06029e3acded0a12', 'Dongo the Giant', 'killedBy', '6191091c06029e3acded0ace', "Night's Watchman"),
#  ('6191091c06029e3acded0a14', 'Dontos Hollard', 'killedBy', '6191091c06029e3acded0ae2', 'Petyr Baelish'),
#  ('6191091c06029e3acded0a15', 'Doran Martell', 'killedBy', '6191091c06029e3acded0a1f', 'Ellaria Sand'),
#  ('6191091c06029e3acded0b58', 'Xaro Xhoan Daxos', 'killedBy', '6191091c06029e3acded0a0d', 'Daenerys Targaryen'),
#  ('6191091c06029e3acded0b59', 'Yara Greyjoy', 'parents', '6191091c06029e3acded09f2', 'Balon Greyjoy'),
#  ('6191091c06029e3acded0b59', 'Yara Greyjoy', 'siblings', '6191091c06029e3acded0b31', 'Theon Greyjoy'),
#  ('6191091c06029e3acded0b5b', 'Ygritte', 'marriedEngaged', '6191091c06029e3acded0a5c', 'Jon Snow'),
#  ('6191091c06029e3acded0b5b', 'Ygritte', 'killedBy', '6191091c06029e3acded0ada', 'Olly'),
#  ('6191091c06029e3acded0b5b', 'Ygritte', 'killed', '6191091c06029e3acded0ae7', 'Pypar'),
#  ('6191091c06029e3acded0b5c', 'Yohn Royce', 'parentOf', '6191091c06029e3acded0b49', 'Waymar Royce'),
#  ('6191091c06029e3acded0b5d', 'Yoren', 'killedBy', '6191091c06029e3acded09e9', 'Amory Lorch')]

# %%
# %%sql
#
# use S22_W4111_HW1;
#
# alter table character_relationships
#     modify source_character_id varchar(128) not null;
#
# alter table character_relationships
#     modify sourceCharacterName varchar(52) null;
#
# alter table character_relationships
#     modify target_character_id varchar(128) null;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 785 rows affected.
# 785 rows affected.
# 785 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-140-d9cdfdc2afc6> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', '\nuse S22_W4111_HW1;\n\nalter table character_relationships\n    modify source_character_id varchar(128) not null;\n\nalter table character_relationships\n    modify sourceCharacterName varchar(52) null;\n\nalter table character_relationships\n    modify target_character_id varchar(128) null;\n\n')
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# D:\Software\Anaconda\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# D:\Software\Anaconda\lib\site-packages\sql\magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# D:\Software\Anaconda\lib\site-packages\sql\run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\engine\cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# D:\Software\Anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# # Programming Track

# %% [markdown]
# Note: If you have activated [student license](https://www.jetbrains.com/community/education/#students) when installing Datagrip, you can also use Pycharm [Professional version](https://www.jetbrains.com/pycharm/download/#section=mac) instead of Community edition.

# %% [markdown]
# ## Tasks
#
# - You will create and modify files in the directory ```<uni>_web_src.```
#
#
# - You will use the database that comes with the book, e.g. ```db_book,``` that you previously installed.
#
#
# - Your web application will support ```GET``` on the path ```/api/db_book/students/<ID>.``` This means you have to implement two things:
#     1. A function in ```application.py``` that implements the path endpoint.
#     2. A method on a class ```Student``` that connects to the database, runs the SQL and returns the result. The project has been updated to have implementation templates for where your code goes.
#
#
# - For submission, you must copy your code from the Python file below to show your code.
#
#
# - You must include a screenshot of calling your application from a browser.

# %% [markdown]
# ## Modified application.py

# %% [markdown]
# ```
# from flask import Flask, Response, request
# import json
# from datetime import datetime
# import rest_utils
#
# app = Flask(__name__)
#
#
# ##################################################################################################################
#
# # DFF TODO A real service would have more robust health check methods.
# # This path simply echoes to check that the app is working.
# # The path is /health and the only method is GETs
# @app.route("/health", methods=["GET"])
# def health_check():
#     rsp_data = {"status": "healthy", "time": str(datetime.now())}
#     rsp_str = json.dumps(rsp_data)
#     rsp = Response(rsp_str, status=200, content_type="application/json")
#     return rsp
#
#
# # TODO Remove later. Solely for explanatory purposes.
# # The method take any REST request, and produces a response indicating what
# # the parameters, headers, etc. are. This is simply for education purposes.
# #
# @app.route("/api/demo/<parameter1>", methods=["GET", "POST", "PUT", "DELETE"])
# @app.route("/api/demo/", methods=["GET", "POST", "PUT", "DELETE"])
# def demo(parameter1=None):
#     """
#     Returns a JSON object containing a description of the received request.
#
#     :param parameter1: The first path parameter.
#     :return: JSON document containing information about the request.
#     """
#
#     # DFF TODO -- We should wrap with an exception pattern.
#     #
#
#     # Mostly for isolation. The rest of the method is isolated from the specifics of Flask.
#     inputs = rest_utils.RESTContext(request, {"parameter1": parameter1})
#
#     # DFF TODO -- We should replace with logging.
#     r_json = inputs.to_json()
#     msg = {
#         "/demo received the following inputs": inputs.to_json()
#     }
#     print("/api/demo/<parameter> received/returned:\n", msg)
#
#     rsp = Response(json.dumps(msg), status=200, content_type="application/json")
#     return rsp
#
# ##################################################################################################################
#
#
# @app.route("/api/db_book/students/<ID>", methods=["GET"])
# def get_student_by_id(ID):
#     #
#     # Your code goes here.
#     #
#     pass
#
#
# if __name__ == '__main__':
#     app.run(host="0.0.0.0", port=5000)
#
# ```

# %% [markdown]
# ## Modified student_resource.py

# %% [markdown]
# ```
#
# class Student:
#
#     def __init__(self):
#         # You may have to put code here.
#         pass
#
#     def get_by_id(self, ID):
#         # Connect to DB.
#         # Form SQL
#         # Run query
#         # return result
#         pass
# ```

# %% [markdown]
# ## Screen Capture of Calling from Browser
